# %% [markdown]
# # <Problem Title>
#
# **Link:** [<URL>](https://leetcode.com/problems/3sum/description/?envType=company&envId=google&favoriteSlug=google-thirty-days)
#
# **Category:** String
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Intuition / Patterns
# - Key ideas:
# - Observations:
# - Potential pitfalls:

# %% [markdown]
# ## Approach 1 — Brute Force
# **Idea:** <explain in your own words>
#
# **Time:** O(?)  |  **Space:** O(?)

# %%
# Code — Approach 1
class Solution(object):
    def threeSum(self, nums):
        """
        :type nums: List[int]
        :rtype: List[List[int]]
        """
        res = []
        for i in range(len(nums)):
            print("i",i)
            i_com = 0 - nums[i]
            for j in range(i+1,len(nums),1):
                print(" j",j)
                j_com = i_com - nums[j]
                for k in range(j+1, len(nums),1):
                    print("  k",k)
                    if nums[k] == j_com:
                        res.append([nums[i],nums[j],nums[k]])
        unique = {tuple(sorted(l)) for l in res} 
        result = [list(u) for u in unique]
        return result

# %% [markdown]
# ## Approach 2 — optimized
# **Idea:** <sliding window / hash map / two pointers / etc.>
#
# **Time:** O(n)  |  **Space:** O(n)

# %%
class Solution(object):
    def threeSum(self, nums):
        """
        :type nums: List[int]
        :rtype: List[List[int]]
        """
        nums = sorted(nums)
        res = []
        for first in range(len(nums)):
            if first>0 and nums[first] == nums[first-1]: continue
            target = - nums[first]
            left = first+1
            right = len(nums)-1
            while left<right:
                if nums[left] + nums[right] == target:
                    res.append([nums[first], nums[left], nums[right]])
                    left += 1
                    right -= 1
                    while left<right and nums[left]==nums[left-1]:
                        left += 1
                    while left<right and nums[right]==nums[right+1]:
                        right -= 1
                elif nums[left] + nums[right] < target:
                    left += 1
                else:
                    right -= 1
        return res

# dvdfa    abcabcabc  tmmzuxt

# %% [markdown]
# ## Correctness & Edge Cases
# - Why does this work?
# - Edge cases: <empty input, single element, all same, very large>

# %%
# Quick Tests
def run_tests():
    tests = []  # add (input, expected)
    for i, (inp, exp) in enumerate(tests, 1):
        # res = solve_optimized(*inp)
        res = None  # placeholder
        print(f"Test {i}: got={res}, expected={exp}")

run_tests()

# %% [markdown]
# ## Notes / Pitfalls
# - <Record any mistakes or insights for future reference>
