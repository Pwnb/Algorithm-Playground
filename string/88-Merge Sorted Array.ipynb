# %% [markdown]
# # <Problem Title>
#
# **Link:** [<URL>](https://leetcode.com/problems/merge-sorted-array/?envType=company&envId=google&favoriteSlug=google-thirty-days)
#
# **Category:**
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Intuition / Patterns
# - Key ideas:
# - Observations:
# - Potential pitfalls:

# %% [markdown]
# ## Approach 1 — Brute Force
# **Idea:** <explain in your own words>
#
# **Time:** O(?)  |  **Space:** O(?)

# %%
# Code — Approach 1
def solve_bruteforce(*args, **kwargs):
    pass

# %% [markdown]
# ## Approach 2 — Optimized
# **Idea:** <sliding window / hash map / two pointers / etc.>
#
# **Time:** O(?)  |  **Space:** O(?)

# %%
class Solution(object):
    def merge(self, nums1, m, nums2, n):
        """
        :type nums1: List[int]
        :type m: int
        :type nums2: List[int]
        :type n: int
        :rtype: None Do not return anything, modify nums1 in-place instead.
        """
        # 246000 135  123000 456
        p1 = m-1
        p2 = n-1
        for p in range(m+n-1, -1, -1):
            if p2 <0: break
            if p1>=0 and nums1[p1] > nums2[p2]:
                nums1[p] = nums1[p1]
                p1 -= 1
            else:
                nums1[p] = nums2[p2]
                p2 -= 1

# %% [markdown]
# ## Correctness & Edge Cases
# - Why does this work?
# - Edge cases: <empty input, single element, all same, very large>

# %%
# Quick Tests
def run_tests():
    tests = []  # add (input, expected)
    for i, (inp, exp) in enumerate(tests, 1):
        # res = solve_optimized(*inp)
        res = None  # placeholder
        print(f"Test {i}: got={res}, expected={exp}")

run_tests()

# %% [markdown]
# ## Notes / Pitfalls
# - <Record any mistakes or insights for future reference>
